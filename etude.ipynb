# %%
import json
from google.cloud import bigquery
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('data/case-study-ds-sa.json') as f:
    info = json.load(f)
client = bigquery.Client.from_service_account_info(info)

# %%
for table in ["test2", "test3", "test4"]:
    q = f"""
    SELECT 
        COUNT(DISTINCT consolidated_user_id) AS num_users,
        COUNT(*) AS num_events
    FROM `tmp-case-study-ds.case_study.{table}`
    """
    res = client.query(q).to_dataframe(create_bqstorage_client=False) #API Storage refusé, je dois prendre REST
    
    print(f"Table {table}: {res['num_users'][0]} utilisateurs, {res['num_events'][0]} événements")
# Out:
# Table test2: 42699 utilisateurs, 28779003 événements
# Table test3: 16750 utilisateurs, 6596362 événements
# Table test4: 16870 utilisateurs, 48181829 événements

# %%
# Regardons juste une ligne pour voir les noms de colonnes
check_cols = "SELECT * FROM `tmp-case-study-ds.case_study.test4` LIMIT 1"
df_check = client.query(check_cols).to_dataframe(create_bqstorage_client=False)
print(df_check.columns)
# Out:
# Index(['consolidated_user_id', 'domain_id', 'visit_id', 'visit_date',
#        'local_start_time', 'local_end_time', 'time_spent_seconds',
#        'product_name', 'main_feature'],
#       dtype='object')

# %%
sql_get_domains = """
SELECT DISTINCT domain_id 
FROM `tmp-case-study-ds.case_study.test4` 
WHERE domain_id IS NOT NULL
"""
domains_df = client.query(sql_get_domains).to_dataframe(create_bqstorage_client=False)
domain_list = domains_df['domain_id'].tolist()

print(f"Métiers trouvés : {domain_list}")
# Out:
# Métiers trouvés : ['INFORMATIONSYSTEM', 'HUMANRESOURCES', 'GUIDANCE', 'OFFRE', 'RETAIL', 'WEB', 'DIGITALMERCH', 'COMMUNICATION', 'FINANCE', 'REALESTATE', 'LEGALCOMP', 'PASSION', 'INDUSTRY', 'LOGISTIC']

# %%
for domain in domain_list : 

    q_metier = """
    SELECT 
        domain_id, 
        product_name, 
        COUNT(*) as nombre_utilisations
    FROM `tmp-case-study-ds.case_study.test4`
    GROUP BY domain_id, product_name
    ORDER BY domain_id, nombre_utilisations DESC
    """

    df_metier = client.query(q_metier).to_dataframe(create_bqstorage_client=False)
    df_metier.head()
    # Pour voir le résultat pour un métier spécifique (ex: MARKETING)
    print(df_metier[df_metier['domain_id'] == f'{domain}'].head(5))
    print('-'*50)
# Out:
#               domain_id     product_name  nombre_utilisations
# 3157  INFORMATIONSYSTEM            Gmail              2727198
# 3158  INFORMATIONSYSTEM  Google Calendar              1297745
# 3159  INFORMATIONSYSTEM      Google Meet               946591
# 3160  INFORMATIONSYSTEM    Google Sheets               943187
# 3161  INFORMATIONSYSTEM      Google Chat               715215
# --------------------------------------------------
#            domain_id     product_name  nombre_utilisations
# 1807  HUMANRESOURCES            Gmail               633387
# 1808  HUMANRESOURCES    Google Sheets               359629
# 1809  HUMANRESOURCES  Google Calendar               247615
# 1810  HUMANRESOURCES    Google Slides               193640
# 1811  HUMANRESOURCES     Google Drive               143538
# --------------------------------------------------
#      domain_id     product_name  nombre_utilisations
# 1509  GUIDANCE            Gmail               177761
# 1510  GUIDANCE    Google Sheets                83831
# 1511  GUIDANCE  Google Calendar                75217
# 1512  GUIDANCE    Google Slides                54751
# 1513  GUIDANCE     Google Drive                30229
# --------------------------------------------------
#      domain_id     product_name  nombre_utilisations
# 5667     OFFRE            Gmail               370130
# 5668     OFFRE    Google Sheets               187057
# 5669     OFFRE    Google Slides               173768
# 5670     OFFRE  Google Calendar               155184
# 5671     OFFRE     Google Drive                61824
# --------------------------------------------------
#      domain_id     product_name  nombre_utilisations
# 7267    RETAIL            Gmail              3388602
# 7268    RETAIL    Google Sheets              2689374
# 7269    RETAIL       Horoquartz              1277003
# 7270    RETAIL  Google Calendar              1056758
# 7271    RETAIL    Google Slides               989581
# --------------------------------------------------
#      domain_id     product_name  nombre_utilisations
# 8400       WEB            Gmail               145583
# 8401       WEB    Google Sheets                84337
# 8402       WEB    Google Slides                42409
# 8403       WEB  Google Calendar                40346
# 8404       WEB         Sprinklr                34754
# --------------------------------------------------
#         domain_id     product_name  nombre_utilisations
# 725  DIGITALMERCH            Gmail                17345
# 726  DIGITALMERCH    Google Slides                10599
# 727  DIGITALMERCH    Google Sheets                 7525
# 728  DIGITALMERCH  Google Calendar                 6780
# 729  DIGITALMERCH     Google Drive                 3908
# --------------------------------------------------
#        domain_id     product_name  nombre_utilisations
# 0  COMMUNICATION            Gmail               607971
# 1  COMMUNICATION    Google Sheets               293541
# 2  COMMUNICATION  Google Calendar               253689
# 3  COMMUNICATION    Google Slides               238045
# 4  COMMUNICATION      Google Docs               118829
# --------------------------------------------------
#     domain_id     product_name  nombre_utilisations
# 823   FINANCE            Gmail              1053597
# 824   FINANCE    Google Sheets               714448
# 825   FINANCE  Google Calendar               357931
# 826   FINANCE    Google Slides               201785
# 827   FINANCE      Google Docs               193463
# --------------------------------------------------
#        domain_id     product_name  nombre_utilisations
# 6971  REALESTATE            Gmail               122283
# 6972  REALESTATE    Google Sheets                60646
# 6973  REALESTATE  Google Calendar                43873
# 6974  REALESTATE     Google Drive                31156
# 6975  REALESTATE      Google Docs                20465
# --------------------------------------------------
#       domain_id     product_name  nombre_utilisations
# 4888  LEGALCOMP            Gmail                14406
# 4889  LEGALCOMP    Google Sheets                 7064
# 4890  LEGALCOMP  Google Calendar                 5297
# 4891  LEGALCOMP      Google Docs                 3978
# 4892  LEGALCOMP          Workiva                 3866
# --------------------------------------------------
#      domain_id     product_name  nombre_utilisations
# 6170   PASSION            Gmail               994503
# 6171   PASSION    Google Sheets               480312
# 6172   PASSION  Google Calendar               454956
# 6173   PASSION    Google Slides               375862
# 6174   PASSION     Google Drive               179254
# --------------------------------------------------
#      domain_id     product_name  nombre_utilisations
# 2382  INDUSTRY            Gmail              1280237
# 2383  INDUSTRY    Google Sheets               759524
# 2384  INDUSTRY  Google Calendar               552119
# 2385  INDUSTRY    Google Slides               355493
# 2386  INDUSTRY      Google Meet               246279
# --------------------------------------------------
#      domain_id     product_name  nombre_utilisations
# 5003  LOGISTIC            Gmail              1194179
# 5004  LOGISTIC    Google Sheets               905261
# 5005  LOGISTIC  Google Calendar               384350
# 5006  LOGISTIC    Google Slides               251947
# 5007  LOGISTIC     Google Drive               198003
# --------------------------------------------------

# %%
def save_workflow_chart(df, domaine):
    plt.figure(figsize=(10, 6))
    # On prend le top 10
    top_df = df.head(10).sort_values('frequency', ascending=True) # Tri inversé pour l'affichage
    
    # Création du barplot horizontal
    bars = plt.barh(top_df['workflow_chain'], top_df['frequency'], color='#4c72b0')
    
    plt.title(f"Top 10 Workflows - {domaine}", fontsize=14)
    plt.xlabel("Fréquence (Nombre de sessions)", fontsize=12)
    plt.tight_layout()
    
    # Sauvegarde
    filename = f"chart_{domaine}.png"
    plt.savefig(filename)
    plt.close() # On ferme pour ne pas surcharger la mémoire
    print(f"Graphique sauvegardé : {filename}")

# %%
# Dictionnaire pour stocker les résultats si tu veux faire des graphiques après
all_results = {}

# 2. La Boucle Automatique
for domaine in domain_list:
    print(f"\n ANALYSE DU DOMAINE : {domaine}")
    
    # La fameuse requête "Full Stack" (Nettoyage + Session + Workflow)
    query_loop = f"""
    WITH raw_data AS (
        SELECT 
            consolidated_user_id,
            product_name,
            local_start_time,
            local_end_time,
            -- On regarde l'app d'avant pour dédoublonner
            LAG(product_name) OVER (PARTITION BY consolidated_user_id ORDER BY local_start_time) as prev_app,
            LAG(local_end_time) OVER (PARTITION BY consolidated_user_id ORDER BY local_start_time) as prev_end
        FROM `tmp-case-study-ds.case_study.test4`
        WHERE domain_id = '{domaine}'
    ),
    filtered_events AS (
        -- On supprime les répétitions immédiates (A -> A) et on calcule le gap
        SELECT *,
            TIMESTAMP_DIFF(local_start_time, prev_end, SECOND) as gap
        FROM raw_data
        WHERE product_name != prev_app OR prev_app IS NULL
    ),
    sessionized AS (
        -- On coupe si > 30 min
        SELECT *,
            SUM(CASE WHEN gap > 1800 OR gap IS NULL THEN 1 ELSE 0 END) 
            OVER (PARTITION BY consolidated_user_id ORDER BY local_start_time) as session_id
        FROM filtered_events
    ),
    workflows AS (
        -- On crée la chaîne
        SELECT
            consolidated_user_id,
            session_id,
            STRING_AGG(product_name, ' -> ' ORDER BY local_start_time) as workflow_chain
        FROM sessionized
        GROUP BY consolidated_user_id, session_id
    )
    SELECT 
        workflow_chain,
        COUNT(*) as frequency
    FROM workflows
    GROUP BY workflow_chain
    ORDER BY frequency DESC
    LIMIT 20
    """
    
    # Exécution
    try:
        df_res = client.query(query_loop).to_dataframe(create_bqstorage_client=False)
        all_results[domaine] = df_res
        print(df_res)

        if not df_res.empty:
            save_workflow_chart(df_res, domaine)
            
    except Exception as e:
        print(f"Erreur sur le domaine {domaine}: {e}")

print("\n Analyse terminée pour tous les métiers.")
# Out:
#  ANALYSE DU DOMAINE : INFORMATIONSYSTEM
#                        workflow_chain  frequency
# 0                               Gmail       2446
# 1                     Google Calendar       1369
# 2                         Google Chat        854
# 3                               COM2U        744
# 4                              Github        730
# 5                       Google Gemini        647
# 6            Gmail -> Google Calendar        482
# 7                      COM2U -> Gmail        481
# 8                       Google Sheets        455
# 9            Google Calendar -> Gmail        446
# 10                               Jira        270
# 11                        Google Meet        255
# 12               Google Chat -> Gmail        229
# 13  Gmail -> Google Calendar -> Gmail        224
# 14                      Google Slides        180
# 15                            ChatGPT        179
# 16                        Google Docs        176
# 17     Google Calendar -> Google Meet        158
# 18                         Confluence        152
# 19                    Gmail -> Github        151
# Graphique sauvegardé : chart_INFORMATIONSYSTEM.png
#
#  ANALYSE DU DOMAINE : HUMANRESOURCES
#                                        workflow_chain  frequency
# 0                                               Gmail        285
# 1                                     Google Calendar        137
# 2                                               COM2U         90
# 3                                       Google Sheets         84
# 4                            Gmail -> Google Calendar         83
# 5                                      COM2U -> Gmail         76
# 6                                       Google Slides         64
# 7                            Google Calendar -> Gmail         49
# 8                   Gmail -> Google Calendar -> Gmail         41
# 9                              Gmail -> Google Sheets         36
# 10                                      Google Gemini         34
# 11                                       Google Drive         33
# 12                                            Outlook         30
# 13                                        Google Docs         24
# 14                           COM2U -> Google Calendar         22
# 15                             Google Sheets -> Gmail         22
# 16        Google Calendar -> Gmail -> Google Calendar         20
# 17                             Gmail -> Google Slides         20
# 18                  COM2U -> Gmail -> Google Calendar         20
# 19  Gmail -> Google Calendar -> Gmail -> Google Ca...         20
# Graphique sauvegardé : chart_HUMANRESOURCES.png
#
#  ANALYSE DU DOMAINE : GUIDANCE
#                                        workflow_chain  frequency
# 0                                               Gmail         64
# 1                                     Google Calendar         28
# 2                            Gmail -> Google Calendar         24
# 3                                       Google Sheets         18
# 4                                       Google Slides         17
# 5                                               COM2U         16
# 6                            Google Calendar -> Gmail         12
# 7                   Gmail -> Google Calendar -> Gmail         10
# 8                                       Google Gemini          9
# 9                                        Google Drive          9
# 10        Google Calendar -> Gmail -> Google Calendar          8
# 11                             Gmail -> Google Sheets          8
# 12                               Gmail -> Google Docs          7
# 13                                            ChatGPT          7
# 14                               Google Docs -> Gmail          6
# 15   Gmail -> Google Sheets -> Gmail -> Google Sheets          5
# 16  Gmail -> Google Calendar -> Gmail -> Google Ca...          5
# 17                      Google Drive -> Google Sheets          5
# 18                                            Outlook          5
# 19  Gmail -> Google Calendar -> Gmail -> Google Ca...          5
# Graphique sauvegardé : chart_GUIDANCE.png
#
#  ANALYSE DU DOMAINE : OFFRE
#                                        workflow_chain  frequency
# 0                                               Gmail        257
# 1                                     Google Calendar        124
# 2                                               COM2U         85
# 3                                       Google Sheets         77
# 4                                       Google Slides         73
# 5                                      COM2U -> Gmail         60
# 6                            Gmail -> Google Calendar         59
# 7                            Google Calendar -> Gmail         52
# 8                                       Google Gemini         45
# 9                              Gmail -> Google Sheets         41
# 10                                        Google Docs         38
# 11                                       Google Drive         37
# 12                  Gmail -> Google Calendar -> Gmail         36
# 13                             Gmail -> Google Slides         31
# 14  Gmail -> Google Calendar -> Gmail -> Google Ca...         28
# 15                             Google Sheets -> Gmail         20
# 16                              Gmail -> Google Drive         17
# 17  Gmail -> Google Calendar -> Gmail -> Google Ca...         16
# 18                             Google Slides -> Gmail         16
# 19                                        Google Meet         16
# Graphique sauvegardé : chart_OFFRE.png
#
#  ANALYSE DU DOMAINE : RETAIL
#                        workflow_chain  frequency
# 0                               Gmail      13924
# 1                               Icare       8501
# 2                       Google Sheets       6091
# 3   Horoquartz -> COM2U -> Horoquartz       3354
# 4                          Horoquartz       3354
# 5                 Horoquartz -> COM2U       3177
# 6              Gmail -> Google Sheets       2966
# 7                               COM2U       2606
# 8                        Google Drive       2496
# 9                       Google Slides       2106
# 10                     COM2U -> Gmail       1873
# 11                     Icare -> Gmail       1823
# 12                     Gmail -> Icare       1592
# 13             Gmail -> Google Slides       1224
# 14                    Google Calendar       1211
# 15              Gmail -> Google Drive       1151
# 16             Google Sheets -> Gmail       1144
# 17                        Google Docs       1130
# 18            Icare -> Gmail -> Icare        984
# 19    Gmail -> Google Sheets -> Gmail        981
# Graphique sauvegardé : chart_RETAIL.png
#
#  ANALYSE DU DOMAINE : WEB
#                        workflow_chain  frequency
# 0                               Gmail         87
# 1                      COM2U -> Gmail         45
# 2                       Google Sheets         37
# 3                     Google Calendar         26
# 4                               COM2U         25
# 5                       Google Gemini         23
# 6              Gmail -> Google Sheets         17
# 7                             ChatGPT         14
# 8              Gmail -> Google Gemini         14
# 9                       Google Slides         12
# 10           Gmail -> Google Calendar         11
# 11           Google Calendar -> Gmail          7
# 12    COM2U -> Gmail -> Google Sheets          6
# 13                       Google Drive          6
# 14                            Outlook          6
# 15            Gmail -> COM2U -> Gmail          6
# 16    Gmail -> Google Sheets -> Gmail          5
# 17  Gmail -> Google Calendar -> Gmail          5
# 18                     Gmail -> Icare          5
# 19             Google Gemini -> Gmail          5
# Graphique sauvegardé : chart_WEB.png
#
#  ANALYSE DU DOMAINE : DIGITALMERCH
#                                        workflow_chain  frequency
# 0                                               Gmail         14
# 1                                       Google Slides         11
# 2                                      COM2U -> Gmail         10
# 3                                     Google Calendar          8
# 4                            Google Calendar -> Gmail          6
# 5                                               COM2U          4
# 6                                         Google Meet          4
# 7                            Gmail -> Google Calendar          4
# 8                     Gmail -> Google Slides -> Gmail          3
# 9                                        Google Drive          3
# 10        Google Calendar -> Gmail -> Google Calendar          3
# 11                  COM2U -> Gmail -> Google Calendar          3
# 12                                            Outlook          3
# 13                              Gmail -> Google Drive          3
# 14                     Gmail -> Google Drive -> Gmail          3
# 15  Google Calendar -> Gmail -> Google Calendar ->...          3
# 16  Gmail -> Google Calendar -> Gmail -> Google Ca...          2
# 17                              Google Drive -> Gmail          2
# 18              Google Drive -> Gmail -> Google Drive          2
# 19                  Gmail -> Google Calendar -> Gmail          2
# Graphique sauvegardé : chart_DIGITALMERCH.png
#
#  ANALYSE DU DOMAINE : COMMUNICATION
#                                 workflow_chain  frequency
# 0                                        Gmail        369
# 1                              Google Calendar        182
# 2                                        COM2U        126
# 3                                Google Sheets        105
# 4                               COM2U -> Gmail         96
# 5                                Google Slides         80
# 6                     Google Calendar -> Gmail         63
# 7                                      ChatGPT         61
# 8                     Gmail -> Google Calendar         53
# 9                                      Outlook         45
# 10                                Google Drive         44
# 11           Gmail -> Google Calendar -> Gmail         44
# 12                               Google Gemini         44
# 13                                 Google Docs         44
# 14                      Gmail -> Google Sheets         39
# 15  COM2U -> Gmail -> Google Calendar -> Gmail         26
# 16           COM2U -> Gmail -> Google Calendar         24
# 17                    COM2U -> Google Calendar         24
# 18                      Gmail -> Google Gemini         23
# 19                      Google Sheets -> Gmail         21
# Graphique sauvegardé : chart_COMMUNICATION.png
#
#  ANALYSE DU DOMAINE : FINANCE
#                                       workflow_chain  frequency
# 0                                              Gmail        443
# 1                                    Google Calendar        228
# 2                                              COM2U        207
# 3                                      Google Sheets        176
# 4                           Gmail -> Google Calendar        109
# 5                                     COM2U -> Gmail         98
# 6                             Gmail -> Google Sheets         91
# 7                                      Google Gemini         80
# 8                  Gmail -> Google Calendar -> Gmail         76
# 9                           Google Calendar -> Gmail         65
# 10                                           Outlook         60
# 11                   Gmail -> Google Sheets -> Gmail         54
# 12                                     Google Slides         49
# 13                                       Google Docs         45
# 14                                       Google Chat         43
# 15                            Google Sheets -> Gmail         43
# 16                                      Google Drive         38
# 17                                           ChatGPT         35
# 18                 COM2U -> Gmail -> Google Calendar         31
# 19  Gmail -> Google Sheets -> Gmail -> Google Sheets         29
# Graphique sauvegardé : chart_FINANCE.png
#
#  ANALYSE DU DOMAINE : REALESTATE
#                                        workflow_chain  frequency
# 0                                               Gmail        113
# 1                                      COM2U -> Gmail         36
# 2                                       Google Sheets         34
# 3                                     Google Calendar         27
# 4                                            GuardTek         26
# 5                            Gmail -> Google Calendar         24
# 6                                               COM2U         20
# 7                              Gmail -> Google Sheets         17
# 8                                   GuardTek -> Gmail         17
# 9                            Google Calendar -> Gmail         12
# 10                  Gmail -> Google Calendar -> Gmail         11
# 11                               Gmail -> Google Docs         10
# 12                                       Google Drive         10
# 13  Gmail -> Google Calendar -> Gmail -> Google Ca...         10
# 14                                  Gmail -> GuardTek          9
# 15                             Google Sheets -> Gmail          7
# 16         COM2U -> Gmail -> Google Calendar -> Gmail          7
# 17                                        Google Docs          7
# 18                                      Google Gemini          7
# 19                      Google Drive -> Google Sheets          5
# Graphique sauvegardé : chart_REALESTATE.png
#
#  ANALYSE DU DOMAINE : LEGALCOMP
#                                        workflow_chain  frequency
# 0                                               Gmail          8
# 1                            Gmail -> Google Calendar          7
# 2                            Google Calendar -> Gmail          4
# 3   Gmail -> Google Calendar -> Gmail -> Google Ca...          3
# 4                                            Linkedin          3
# 5                   Gmail -> Google Calendar -> Gmail          3
# 6                                     Google Calendar          3
# 7                                       Google Slides          2
# 8                                         Google Chat          2
# 9                              Google Sheets -> Gmail          2
# 10                               Gmail -> Google Chat          2
# 11                  COM2U -> Gmail -> Google Calendar          2
# 12  Gmail -> Google Drive -> Gmail -> Google Drive...          1
# 13  Gmail -> Google Docs -> Gmail -> Google Drive ...          1
# 14  Google Calendar -> Google Meet -> Google Calen...          1
# 15  Gmail -> Google Slides -> Gmail -> Google Site...          1
# 16  COM2U -> Gmail -> Google Calendar -> Gmail -> ...          1
# 17  Gmail -> Google Calendar -> Gmail -> Google Ge...          1
# 18  Google Calendar -> Gmail -> Google Docs -> Goo...          1
# 19  Gmail -> Google Sheets -> Gmail -> Workiva -> ...          1
# Graphique sauvegardé : chart_LEGALCOMP.png
#
#  ANALYSE DU DOMAINE : PASSION
#                                        workflow_chain  frequency
# 0                                               Gmail        886
# 1                                     Google Calendar        455
# 2                                               COM2U        233
# 3                                       Google Slides        230
# 4                                       Google Sheets        224
# 5                            Gmail -> Google Calendar        215
# 6                                      COM2U -> Gmail        181
# 7                            Google Calendar -> Gmail        159
# 8                                       Google Gemini        154
# 9                   Gmail -> Google Calendar -> Gmail        140
# 10                                       Google Drive        123
# 11                             Gmail -> Google Sheets        111
# 12                             Gmail -> Google Slides         90
# 13  Gmail -> Google Calendar -> Gmail -> Google Ca...         87
# 14                                            Outlook         84
# 15        Google Calendar -> Gmail -> Google Calendar         84
# 16                                               Miro         63
# 17                                            ChatGPT         59
# 18                             Google Sheets -> Gmail         51
# 19  Gmail -> Google Calendar -> Gmail -> Google Ca...         51
# Graphique sauvegardé : chart_PASSION.png
#
#  ANALYSE DU DOMAINE : INDUSTRY
#                                        workflow_chain  frequency
# 0                                               Gmail        794
# 1                                     Google Calendar        365
# 2                                       Google Sheets        263
# 3                                               COM2U        218
# 4                            Gmail -> Google Calendar        204
# 5                                      COM2U -> Gmail        193
# 6                                       Google Slides        160
# 7                              Gmail -> Google Sheets        139
# 8                   Gmail -> Google Calendar -> Gmail        136
# 9                            Google Calendar -> Gmail        133
# 10                                       Google Drive        125
# 11                                      Google Gemini        100
# 12                                            Outlook         88
# 13  Gmail -> Google Calendar -> Gmail -> Google Ca...         69
# 14                  COM2U -> Gmail -> Google Calendar         66
# 15                    Gmail -> Google Sheets -> Gmail         63
# 16                             Google Sheets -> Gmail         61
# 17                                        Google Docs         60
# 18        Google Calendar -> Gmail -> Google Calendar         60
# 19  Gmail -> Google Calendar -> Gmail -> Google Ca...         55
# Graphique sauvegardé : chart_INDUSTRY.png
#
#  ANALYSE DU DOMAINE : LOGISTIC
#                                       workflow_chain  frequency
# 0                                              Gmail        836
# 1                                     COM2U -> Gmail        630
# 2                                      Google Sheets        474
# 3                                              COM2U        418
# 4                             Gmail -> Google Sheets        348
# 5                                    Google Calendar        213
# 6                             COM2U -> Google Sheets        210
# 7                      Google Drive -> Google Sheets        140
# 8                    Gmail -> Google Sheets -> Gmail        137
# 9                             Google Sheets -> Gmail        128
# 10                          Gmail -> Google Calendar        127
# 11                   COM2U -> Gmail -> Google Sheets        119
# 12  Gmail -> Google Sheets -> Gmail -> Google Sheets        108
# 13                                      Google Drive        104
# 14                                     Google Slides         98
# 15           Google Sheets -> Gmail -> Google Sheets         92
# 16          COM2U -> Gmail -> Google Sheets -> Gmail         91
# 17                              IBM Cognos Analytics         76
# 18                                           Outlook         75
# 19                 Gmail -> Google Calendar -> Gmail         68
# Graphique sauvegardé : chart_LOGISTIC.png
#
#  Analyse terminée pour tous les métiers.
